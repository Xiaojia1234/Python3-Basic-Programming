# %% [markdown]
# # Python继承

# %% [markdown]
# ### 什么是继承？

# %% [markdown]
# 继承用于指定一个类从其父类获取其大部分或全部功能。它是面向对象编程的一个重要特征。这是一个非常强大的功能，方便用户对现有类进行几个或多个修改来创建一个新的类。新类称为子类或派生类，从其继承属性的主类称为基类或父类。

# %% [markdown]
# 子类或派生类继承父类的功能，向其添加新的功能。它有助于代码的可重用性。下图表示：

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ### 语法-1

# %% [raw]
# class DerivedClassName(BaseClassName):
#     <statement-1>
#     .
#     .
#     .
#     <statement-N>

# %% [markdown]
# ### 语法-2

# %% [raw]
# class DerivedClassName(modulename.BaseClassName):
#     <statement-1>
#     .
#     .
#     .
#     <statement-N>

# %% [markdown]
# ### 参数说明

# %% [markdown]
# 必须在包含派生类的定义的范围中定义名称 BaseClassName.还可以使用其他任意表达式代替基类名称。当在另一个模块中定义基类时要指定模块的名称。

# %% [markdown]
# #### Python继承示例

# %% [markdown]
# 我们来看一个简单的python继承示例，在这个示例中使用两个类：Animal和Dog.Animal是父类或基类，Dog是Animal的子类。

# %% [markdown]
# 在这里。在Animal类中定义了eat()方法，dog()中定义了bark()方法。在这个例子中，我们创建Dog类的实例，并且通过子类的
# 实例调用eat()和bark()方法。由于父属性和行为自动继承到子对象，所以通过子实例也可以调用杜磊和子类的方法。

# %%
class Animal:
    def eat(self):
